# %% [markdown]
# # Check Tensorflow Version  and GPU Availability

# %%
import tensorflow as tf
print('tf version:', tf.__version__)
print('gpu:', tf.config.list_physical_devices('CPU'))
# Out:
# tf version: 2.8.0
# gpu: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import cv2

# %% [markdown]
# # Global Constants

# %%
IMG_DIMEN = 224  
N_COLORS = 3

# %% [markdown]
# # Reading Dataset Function

# %%
from tqdm import tqdm
import numpy as np
import os

def read_data(dir_path):
    X = []
    y = []
    y_map = {'benign': 0, 'malignant': 1}
    for class_name in y_map.keys():
        subdir_path = os.path.join(dir_path, class_name)
        filenames = os.listdir(subdir_path)
        for fname in tqdm(filenames):
            if fname.endswith('.jpg'):
                img_path = os.path.join(subdir_path, fname)
                img = cv2.imread(img_path)
                img = cv2.resize(img, dsize=(IMG_DIMEN, IMG_DIMEN))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = img.reshape((1, IMG_DIMEN, IMG_DIMEN, N_COLORS))
                X.append(img)
                y.append(y_map[class_name])
    X = np.vstack(X).astype('float32')/255.0
    y = np.array(y).astype('int32')
    return X, y

# %% [markdown]
# # We read data in x test ,y test

# %%
X, y = read_data('data/train')
# Out:
# 100%|██████████| 1440/1440 [00:07<00:00, 192.04it/s]
# 100%|██████████| 1197/1197 [00:05<00:00, 224.32it/s]

# %%
print(X.shape)
print(y.shape)
# Out:
# (2637, 224, 224, 3)
# (2637,)

# %%
X_test, y_test = read_data('data/test')
# Out:
# 100%|██████████| 360/360 [00:02<00:00, 176.39it/s]
# 100%|██████████| 300/300 [00:01<00:00, 209.26it/s]

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (660, 224, 224, 3)
# (660,)

# %% [markdown]
# # Splitting X,y into train and validation

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
print('--------------')
print(X_val.shape)
print(y_val.shape)
# Out:
# (1766, 224, 224, 3)
# (1766,)
# --------------
# (871, 224, 224, 3)
# (871,)

# %% [markdown]
# # Visualising and example image

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def imshow(img):
    plt.figure(figsize=(6, 6))
    if N_COLORS == 3:
        plt.imshow(img)
    elif N_COLORS == 1:
         plt.imshow(img, cmap='gray')
    plt.show()

# %%
imshow(X_train[3])

# %% [markdown]
# # Bulding CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense

# %%
model = Sequential()
model.add(Conv2D(16, 7, activation='relu', input_shape=(IMG_DIMEN, IMG_DIMEN, N_COLORS)))
model.add(Conv2D(16, 7, activation='relu'))
model.add(MaxPooling2D(2))
model.add(Conv2D(32, 5, activation='relu'))
model.add(Conv2D(32, 5, activation='relu'))
model.add(MaxPooling2D(2))
model.add(Conv2D(64, 3, activation='relu'))
model.add(Conv2D(64, 3, activation='relu'))
model.add(MaxPooling2D(2))
model.add(GlobalAveragePooling2D())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Training and Validation

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'saved-model/best-model', monitor='val_loss', mode='min', 
    save_weights_only=True, save_best_only=True, verbose=1
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=32,
    epochs=3,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/3
# 56/56 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.5527WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FB422A7D30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FB422A7D30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# Epoch 1: val_loss improved from inf to 0.69231, saving model to saved-model\best-model
# 56/56 [==============================] - 454s 8s/step - loss: 0.6913 - accuracy: 0.5527 - val_loss: 0.6923 - val_accuracy: 0.5327
# Epoch 2/3
# 56/56 [==============================] - ETA: 0s - loss: 0.6889 - accuracy: 0.5527
# Epoch 2: val_loss did not improve from 0.69231
# 56/56 [==============================] - 447s 8s/step - loss: 0.6889 - accuracy: 0.5527 - val_loss: 0.6924 - val_accuracy: 0.5327
# Epoch 3/3
# 56/56 [==============================] - ETA: 0s - loss: 0.6881 - accuracy: 0.5527
# Epoch 3: val_loss improved from 0.69231 to 0.69112, saving model to saved-model\best-model
# 56/56 [==============================] - 427s 8s/step - loss: 0.6881 - accuracy: 0.5527 - val_loss: 0.6911 - val_accuracy: 0.5327

# %% [markdown]
# # Visualizin Training History

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

hist_df = pd.DataFrame(history.history)
hist_df.plot(y=['loss', 'val_loss'], figsize=(12, 8))
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.grid(axis='both')
plt.xticks(np.arange(0, 121, 5))
plt.show()

# %%
hist_df = pd.DataFrame(history.history)
hist_df.plot(y=['accuracy', 'val_accuracy'], figsize=(12, 8))
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Training and Validation Accuracy')
plt.grid(axis='both')
plt.xticks(np.arange(0, 121, 5))
plt.yticks(np.arange(0.5, 1.01, 0.05))
plt.show()

# %% [markdown]
# # Testing

# %%
model.load_weights('saved-model/best-model')
model.evaluate(X_test, y_test)
# Out:
# 21/21 [==============================] - 15s 701ms/step - loss: 0.6891 - accuracy: 0.5455
# [0.6890659928321838, 0.5454545617103577]
